# %%
"""First we import the file and get it's contents"""

# %%
import csv
import pandas as pd

# %%
df = pd.read_csv("./data.csv")
df
# Out:
#      participant_id           id  sex recruit_date postal_code  province  \
# 0                 1  HVH-0001-78  1.0   2020-11-09       08025       1.0
# 1                 2  HVH-0002-78  2.0   2020-11-14       08012       1.0
# 2                 3  HVH-0003-78  1.0   2020-11-16         NaN       1.0
# 3                 4  HVH-0004-78  2.0   2020-11-30         NaN       1.0
# 4                 5  HVH-0005-78  2.0   2020-12-16       08016       1.0
# ...             ...          ...  ...          ...         ...       ...
# 1676        1220-65   90-0075-78  1.0   2020-12-16       08210       1.0
# 1677         1304-1  ESB-0001-78  2.0   2020-12-14       08830       1.0
# 1678         1304-2  ESB-0002-78  1.0   2020-12-17       08830       1.0
# 1679         1304-3  ESB-0003-78  1.0   2020-12-17       08830       1.0
# 1680         1304-4  ESB-0004-78  2.0   2020-12-17       08830       1.0
#
#       family_country row_school  bus  sports_type  ...  other flu_binary  \
# ...

# %%
"""Then we clean the data"""
# Out:
# 'Then we clean the data'

# %%
df = df.drop('participant_id', axis=1)
df = df.drop('recruit_date', axis=1)
df = df.drop('postal_code', axis=1)
df = df.drop('province', axis=1)
df = df.drop('family_country', axis=1)
df = df.drop('row_school', axis=1)
df = df.drop('floor_level', axis=1)
df = df.drop('survey_type', axis=1)
df = df.drop('inclusion_criteria', axis=1)
df = df.drop('housemember_symptoms___1', axis=1)
df = df.drop('housemember_symptoms___2', axis=1)
df = df.drop('housemember_symptoms___3', axis=1)
df = df.drop('housemember_symptoms___4', axis=1)
df = df.drop('housemember_symptoms___5', axis=1)
df = df.drop('persons_home', axis=1)
df = df.drop('simptomatology_date', axis=1)
df = df.drop('date_fever', axis=1)
df = df.drop('end_fever', axis=1)
df = df.drop('other_simptomatology_lliure', axis=1)
df = df.drop('sero_type_response', axis=1)
df = df.drop('sero_method', axis=1)
df = df.drop('sero_date', axis=1)
df = df.drop('sero', axis=1)
df = df.drop('cxr', axis=1)
df = df.drop('ct', axis=1)
df = df.drop('cxr_date', axis=1)
df = df.drop('thoracic_ct_date', axis=1)
df = df.drop('pcr_performed', axis=1)
df = df.drop('pcr_date', axis=1)
df = df.drop('pcr_type', axis=1)
df = df.drop('antigenic_performed', axis=1)
df = df.drop('ag_test_mark', axis=1)
df = df.drop('antigenic_date', axis=1)
df = df.drop('antigenic_sample', axis=1)
df = df.drop('othervirus_performed', axis=1)
df = df.drop('otherviruses_date', axis=1)
df = df.drop('vrs_result', axis=1)
df = df.drop('adeno_result', axis=1)
df = df.drop('flu_a_result', axis=1)
df = df.drop('flu_b_result', axis=1)
df = df.drop('adm_date', axis=1)
df = df.drop('picu_adm', axis=1)
df = df.drop('adm_hospital', axis=1)
df = df.drop('discharge_date', axis=1)
df = df.drop('final_diagnosis_text', axis=1)
df = df.drop('coviral_binary', axis=1)
df = df.drop('coviral_type', axis=1)
df = df.drop('other_viruses_text', axis=1)
df = df.drop('bacterial_infection', axis=1)
df = df.drop('bacterial_type', axis=1)
df = df.drop('clinical_and_diagnosis_data_at_the_admission_time_complete', axis=1)
list_of_shit = ['comorbi_binary',
 'cardiopathy___1',
 'cardiopathy___2',
 'cardiopathy___3',
 'hypertension___1',
 'hypertension___2',
 'hypertension___3',
 'pulmonar_disease___1',
 'pulmonar_disease___2',
 'pulmonar_disease___3',
 'asma___1',
 'asma___2',
 'asma___3',
 'nephrology___1',
 'nephrology___2',
 'nephrology___3',
 'hepatic___1',
 'hepatic___2',
 'hepatic___3',
 'neurologic___1',
 'neurologic___2',
 'neurologic___3',
 'diabetes___1',
 'diabetes___2',
 'diabetes___3',
 'tuberculosi___1',
 'tuberculosi___2',
 'tuberculosi___3',
 'idp___1',
 'idp___2',
 'idp___3',
 'neoplasia___1',
 'neoplasia___2',
 'neoplasia___3',
 'kawasaki___1',
 'kawasaki___2',
 'kawasaki___3',
 'inflammation___1',
 'inflammation___2',
 'inflammation___3',
 'vih_others___1',
 'vih_others___2',
 'vih_others___3',
 'obesity',
 'other']

for shit in list_of_shit:
    df = df.drop(shit, axis=1)

df = df.drop('flu_date', axis=1)
df = df.drop('vaccines_binary', axis=1)
df = df.drop('comorbidities_complete', axis=1)
df = df.drop('survey_end_date', axis=1)
df = df.drop('name_initials_of_the_inter', axis=1)
df = df.drop('comments', axis=1)
df = df.drop('final_outcome_complete', axis=1)
df = df.drop('id', axis=1)
df = df.drop('bus', axis=1)
df = df.drop('sports_type', axis=1)
df = df.drop('sports', axis=1)
df = df.drop('m2', axis=1)
df = df.drop('rooms', axis=1)
df = df.drop('school_symptoms_member___1', axis=1)
df = df.drop('school_symptoms_member___2', axis=1)
df = df.drop('school_symptoms_member___4', axis=1)
df = df.drop('school_symptoms_member___5', axis=1)
df = df.drop('sero_type_response_2', axis=1)
df = df.drop('sat_hb_o2', axis=1)
df = df.drop('final_outcome', axis=1)
df = df.drop('final_classification_of_th', axis=1)

# %%
list(df.columns)
# Out:
# ['sex',
#  'smokers_home',
#  'sympt_epi',
#  'home_confirmed',
#  'school_symptoms',
#  'school_confirmed',
#  'symptoms_binary',
#  'fever',
#  'highest_fever',
#  'total_days_fever',
#  'tos',
#  'cough_first',
#  'crup',
#  'crup_first',
#  'dysphonia',
#  'disfonia_first',
#  'resp',
#  'dyspnea_first',
#  'tachypnea',
#  'tachypnea_first',
#  'ausc_resp',
#  'auscult_first',
#  'wheezing',
#  'crackles',
#  'odynophagia',
#  'odynophagia_first',
#  'nasal_congestion',
#  'nasal_first',
#  'fatiga',
#  'fatigue_first',
#  'headache',
#  'headache_first',
#  'conjuntivitis',
#  'conj_first',
#  'ocular_pain',
#  'ocular_first',
#  'gi_symptoms',
#  'gi_first',
#  'abdominal_pain',
#  'vomiting',
#  'dyarrea',
#  'dermatologic',
#  'skin_first',
#  'rash',
#  'inflam_periferic',
#  'inflam_oral',
#  'adenopathies',
#  'lymph_first',
#  'hepato',
#  'hepato_first',
#  'splenomegaly',
#  'spleno_first',
#  'hemorrhagies',
#  'hemorr_first',
#  'irritability',
# ...

# %%
df
# Out:
#       sex  smokers_home  sympt_epi  home_confirmed  school_symptoms  \
# 0     1.0           2.0        0.0             0.0              0.0
# 1     2.0           2.0        0.0             0.0              0.0
# 2     1.0           2.0        0.0             0.0              0.0
# 3     2.0           2.0        0.0             0.0              NaN
# 4     2.0           2.0        1.0             1.0              NaN
# ...   ...           ...        ...             ...              ...
# 1676  1.0           NaN        0.0             0.0              0.0
# 1677  2.0           NaN        0.0             0.0              0.0
# 1678  1.0           2.0        0.0             0.0              0.0
# 1679  1.0           2.0        0.0             0.0              0.0
# 1680  2.0           1.0        0.0             0.0              1.0
#
#       school_confirmed  symptoms_binary  fever  highest_fever  \
# 0                  0.0              1.0    1.0            1.0
# ...

# %%
"""
    We check Nan value for each column
"""

# %%
not_null = lambda x : x.notnull()
def list_nan_values(df, function):
    check_nan = lambda x : len(df) - len(df[function(x)])
    list_nan_cols = list()
    for col in df.columns:
        list_nan_cols.append((col, check_nan(df[col])))
    return list_nan_cols

# %%
list_nan = list_nan_values(df, not_null)

# %%
list_nan
# Out:
# [('sex', 4),
#  ('smokers_home', 156),
#  ('sympt_epi', 17),
#  ('home_confirmed', 151),
#  ('school_symptoms', 51),
#  ('school_confirmed', 182),
#  ('symptoms_binary', 9),
#  ('fever', 36),
#  ('highest_fever', 699),
#  ('total_days_fever', 827),
#  ('tos', 38),
#  ('cough_first', 881),
#  ('crup', 890),
#  ('crup_first', 1657),
#  ('dysphonia', 44),
#  ('disfonia_first', 1602),
#  ('resp', 43),
#  ('dyspnea_first', 1549),
#  ('tachypnea', 43),
#  ('tachypnea_first', 1604),
#  ('ausc_resp', 328),
#  ('auscult_first', 1526),
#  ('wheezing', 1523),
#  ('crackles', 1528),
#  ('odynophagia', 49),
#  ('odynophagia_first', 1278),
#  ('nasal_congestion', 49),
#  ('nasal_first', 837),
#  ('fatiga', 47),
#  ('fatigue_first', 1322),
#  ('headache', 51),
#  ('headache_first', 1255),
#  ('conjuntivitis', 48),
#  ('conj_first', 1648),
#  ('ocular_pain', 778),
#  ('ocular_first', 1675),
#  ('gi_symptoms', 41),
#  ('gi_first', 1146),
#  ('abdominal_pain', 1147),
#  ('vomiting', 1145),
# ...

# %%
"""
Decisions on NaN values
- sex: Random to empty ones 50%
- 
- 
"""
# Out:
# '\nDecisions on NaN values\n- sex: Random to empty ones 50%\n- \n- \n'

# %%
"""We check wich vaues contain every column"""

# %%
import numpy as np
import math
def get_population(df, column):
    rs = {}
    values = list(column.dropna().unique())
    for val in values:
        rs[val] = len(df[column == val])
    rs[np.nan] = len(column.isnull()[lambda x: x == True])
    return rs
check_values = {}
for col in df.columns:
    check_values[col] = get_population(df,df[col])
check_values
# Out:
# {'sex': {1.0: 934, 2.0: 743, nan: 4},
#  'smokers_home': {2.0: 1074, 1.0: 451, nan: 156},
#  'sympt_epi': {0.0: 1370, 1.0: 294, nan: 17},
#  'home_confirmed': {0.0: 1411, 1.0: 119, nan: 151},
#  'school_symptoms': {0.0: 1531, 1.0: 99, nan: 51},
#  'school_confirmed': {0.0: 1415, 1.0: 84, nan: 182},
#  'symptoms_binary': {1.0: 1647, 0.0: 25, nan: 9},
#  'fever': {1.0: 983, 2.0: 662, nan: 36},
#  'highest_fever': {1.0: 285, 2.0: 535, 3.0: 162, nan: 699},
#  'total_days_fever': {'1': 285,
#   '3': 129,
#   '4': 82,
#   '2': 279,
#   '14': 1,
#   '1 DETERMINACION': 1,
#   '5': 22,
#   '2-3': 1,
#   '48': 1,
#   '6': 11,
#   '1 y medio': 1,
#   '10': 3,
#   '1,5': 3,
#   '38.7': 1,
#   '7': 5,
#   '24 hores': 3,
#   '24hores': 1,
#   '24h': 2,
#   '24horews': 1,
#   'va iniciar febreta a dies alterns una setmana abans, inferior a 37,4. El dia abans de consultar 37,6 mantingut': 1,
#   '16': 1,
#   '0,5': 4,
#   '2 dies ': 2,
#   '3 dies': 1,
#   '1 dia': 1,
#   '1 dia ': 2,
# ...

# %%
df = df.drop('total_days_fever', axis=1)
df = df.drop('sat_hb_o2_value', axis=1)

# %%
check_values = {}
for col in df.columns:
    check_values[col] = get_population(df,df[col])
check_values
# Out:
# {'sex': {1.0: 934, 2.0: 743, nan: 4},
#  'smokers_home': {2.0: 1074, 1.0: 451, nan: 156},
#  'sympt_epi': {0.0: 1370, 1.0: 294, nan: 17},
#  'home_confirmed': {0.0: 1411, 1.0: 119, nan: 151},
#  'school_symptoms': {0.0: 1531, 1.0: 99, nan: 51},
#  'school_confirmed': {0.0: 1415, 1.0: 84, nan: 182},
#  'symptoms_binary': {1.0: 1647, 0.0: 25, nan: 9},
#  'fever': {1.0: 983, 2.0: 662, nan: 36},
#  'highest_fever': {1.0: 285, 2.0: 535, 3.0: 162, nan: 699},
#  'tos': {1.0: 803, 2.0: 840, nan: 38},
#  'cough_first': {1.0: 736, 0.0: 64, nan: 881},
#  'crup': {2.0: 766, 1.0: 24, 3.0: 1, nan: 890},
#  'crup_first': {0.0: 7, 1.0: 17, nan: 1657},
#  'dysphonia': {2.0: 1544, 1.0: 79, 3.0: 14, nan: 44},
#  'disfonia_first': {0.0: 10, 1.0: 69, nan: 1602},
#  'resp': {1.0: 133, 2.0: 1504, 3.0: 1, nan: 43},
#  'dyspnea_first': {1.0: 112, 0.0: 20, nan: 1549},
#  'tachypnea': {1.0: 78, 2.0: 1550, 3.0: 10, nan: 43},
#  'tachypnea_first': {1.0: 66, 0.0: 11, nan: 1604},
# ...

# %%
"""
    We do a heatmap in order to see the correlation between variables, 
    for gruping it in groups and reduce the number of columns
"""

# %%
import seaborn as sns
sns.heatmap(df.corr(), vmin=-1, vmax=1, center= 0)
# Out:
# <AxesSubplot:>

# %%
"""
    Impossible to see nothing so we opted to make an algorithm
    for making groups of strongly correlated variables.
"""

# %%
from collections import defaultdict
cor = df.corr()
correlations = defaultdict(lambda: [])
for c in df.columns:
    series = cor[[c]].drop(c)
    series = series.dropna()
    series = series.transpose()
    var_corr_group = [ col for col in series.columns if series[col].item() >= 0.8]
    correlations[c] = var_corr_group
correlations
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'sex': [],
#              'smokers_home': [],
#              'sympt_epi': [],
#              'home_confirmed': [],
#              'school_symptoms': [],
#              'school_confirmed': [],
#              'symptoms_binary': [],
#              'fever': ['other_simptomatology_4'],
#              'highest_fever': [],
#              'tos': [],
#              'cough_first': ['neuro_first', 'seizures'],
#              'crup': [],
#              'crup_first': [],
#              'dysphonia': [],
#              'disfonia_first': [],
#              'resp': [],
#              'dyspnea_first': ['tachypnea_first',
#               'auscult_first',
#               'taste_first',
#               'smell_first'],
#              'tachypnea': [],
#              'tachypnea_first': ['dyspnea_first', 'auscult_first'],
#              'ausc_resp': [],
#              'auscult_first': ['dyspnea_first', 'tachypnea_first'],
# ...

# %%
"""
    We've seen that other simptomatology 4 has a big group of correlations, so we thought that
    first we shoud separate it's values to diferent cols.
"""

# %%
other_simptomatology_fields = ['other_simptomatology', 'other_simptomatology_3','other_simptomatology_4']
list1 = list(map(lambda x: x == 1 , df['other_simptomatology']))
list2 = list(map(lambda x: x == 1 , df['other_simptomatology_3']))
list3 = list(map(lambda x: x == 1 , df['other_simptomatology_4']))
dolor_toracic = list(map(lambda x, y, z: x or y or z, list1, list2, list3))
list(map(lambda x: 1 if x== 1 else 2, map( , ))
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
# ...
